# %%
#Question 1:
    B.RAINBOW

# %%
#Question 2:
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
#Question 3:
cp=int(input())
sp=int(input())
if(sp-cp>0):
    print("Profit")
elif(sp-cp<0):
    print("Loss")
else:
    print("Neither")
# Out:
# 20
# 30
# Profit

# %%
#Question 4:
euro=int(input())
rupees=euro*80
print(rupees)
# Out:
# 20
# 1600
